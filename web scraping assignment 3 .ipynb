# %%
#import necessary librabies for webscraping with selenium

import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time
import requests
from time import sleep

# %% [markdown]
# Q1: Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitar

# %%
#First connect to the driver

driver= webdriver.Chrome(r"chromedriver_win32.exe")

#open the page in automated chrome browser

driver.get("https://www.amazon.in/")
time.sleep(2)

# %%
# Taking input from user

user_input=input('Enter the Product you which you want to search :')
# Out:
# Enter the Product you which you want to search :guitar

# %%
# Finding search

search=driver.find_element(By.XPATH,'//input[@id="twotabsearchtextbox"]')

# clearing any previous input in search bar

search.clear()

# %%
# Puting input to search button and click on seach

search.send_keys(user_input)

button=driver.find_element(By.XPATH,'//input[@id="nav-search-submit-button"]')
button.click()

# %% [markdown]
# Q2.In the above question, now scrape the following details of each product listed in first 3 pages of your
# search results and save it in a data frame and csv. In case if any product has less than 3 pages in search
# results then scrape all the products available under that product name. Details to be scraped are: "Brand
# Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and
# “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
# Make Empty list to save the scrapped data

brand_name =[]
product = []
price =[]
exchange =[]
excepted_delivery =[]
availability =[]
url =[]

# %%
#First scrape URL of the searched product for first 3 pages
start= 0
end= 3
for page in range(start, end):
    url_tags =driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in url_tags:
        url.append(i.get_attribute('href'))
    time.sleep(2)
    
    # locating next page button and clicking
    
    next_page = driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    next_page.click()
    time.sleep(6)

# %%
len(url)
# Out:
# 151

# %%
for i in url:
    driver.get(i)
    time.sleep(3)

# %%
# Extracting Brand Name
try:
    brand_tags =driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[6]/div[3]/div[4]/div[40]/div/table/tbody/tr[1]/td[2]')
    brand_name.append(brand_tags.text) 
        
except NoSuchElementException:
    brand_name.append('-')
    time.sleep(2)
    
    # Extracting product name
try:
    product_tags =driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[6]/div[3]/div[4]/div[1]/div/h1/span')
    product.append(product_tags.text)
        
except NoSuchElementException:
    product.append('-')
    time.sleep(2)
    
    # Extracting Price
try:
    price_tags =driver.find_element(By.XPATH,'//span[@class="a-price-whole"]')
    price.append(price_tags.text)
        
except NoSuchElementException:
    price.append('-')
    time.sleep(2)
    
    # Extracting Return or exchange details
try:
    ex_tags =driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[6]/div[3]/div[4]/div[22]/div[2]/div/div/div/div[2]/div/ol/li[3]/div/span/div[2]')
    exchange.append(ex_tags.text)
        
except NoSuchElementException:
    exchange.append('-')
    time.sleep(2)
    
    # Extracting Expected Delivery via Xpath
try:
    delivery_tags =driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[6]/div[3]/div[1]/div[3]/div/div[1]/div/div/div/form/div/div/div/div/div[3]/div/div[2]/div[9]/div[1]/div/div/div/span/span[1]')
    excepted_delivery.append(delivery_tags.text)
        
except NoSuchElementException:
    excepted_delivery.append('-')
    time.sleep(2)
    
    # Extracting availability via Xpath
try:
    availability_tags =driver.find_element(By.XPATH,'//span[@class="a-size-medium a-color-success"]')
    availability.append(availability_tags.text)
        
except NoSuchElementException:
    availability.append('-')
    time.sleep(2)

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(brand_name,product,price, exchange,excepted_delivery,availability, url))

data= pd.DataFrame(data_list, 
    columns =['Brand_Name', 'Product', 'Price', 'Return/Exchange','Excepted Delivery','Availability','URL'],
    index=pd.RangeIndex(start=1, stop=152, name='Sr. No.'))

#Print the required data

print ("Details of each product listed in first 3 pages from amazon.com:\n")
data
# Out:
# Details of each product listed in first 3 pages from amazon.com:
#         Brand_Name Product Price Return/Exchange Excepted Delivery  \
# Sr. No.
# 1                -       -     -               -                 -
# 2                -       -     -               -                 -
# 3                -       -     -               -                 -
# 4                -       -     -               -                 -
# 5                -       -     -               -                 -
# ...            ...     ...   ...             ...               ...
# 147              -       -     -               -                 -
# 148              -       -     -               -                 -
# 149              -       -     -               -                 -
# 150              -       -     -               -                 -
# 151              -       -     -               -                 -
#
#         Availability                                                URL
# Sr. No.
# 1           In stock  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2           In stock  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 3                  -  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 4           In stock  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 5           In stock  https://www.amazon.in/Juarez-Acoustic-Cutaway-...
# ...              ...                                                ...
# 147                -  https://www.amazon.in/Yamaha-PAC012-Electric-G...
# 148         In stock  https://www.amazon.in/Medellin-Premium-Acousti...
# 149         In stock  https://www.amazon.in/Blueberry-Acoustic-Guita...
# 150         In stock  https://www.amazon.in/Carlton-Rosewood-Fretboa...
# 151         In stock  https://www.amazon.in/JUAREZ-Electric-Guitar-H...
#
# [151 rows x 7 columns]

# %% [markdown]
# Q3. Write a python program to access the search bar and search button on images.google.com and scrape 10images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"chromedriver_win32.exe")

#open the page in automated chrome browser

driver.get("https://images.google.com/")
time.sleep(5)

# %%
# Scraping for fruits:

# Finding search

search=driver.find_element(By.XPATH,'//textarea[@class="gLFyf"]')

# clearing any previous input in search bar

search.clear()

# Puting 'fruits' to search button and click on seach

search.send_keys('fruits')
button=driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
button.click()

# %%
# Scrolling window using ScrollBy

driver.execute_script("window.scrollBy(0,10000)","")

# %%
image_tag= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

url=[]
for img in image_tag:
    x= img.get_attribute('src')
    if x is not None:
        if(x[0:4] == 'http'):
            url.append(x)

# %%
len(url)
# Out:
# 42

# %%
for i in range(len(url)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(url[i])
    file = open(r"C:\Users\Pavan Krishna\Desktop\flip robo\web scraping 3\fruits" +str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images

# %%
#Scraping for cars:
# Finding search

search=driver.find_element(By.XPATH,'/html/body/c-wiz/c-wiz/div/div[3]/div[2]/div/div[1]/form/div[1]/div[2]/div/div[2]/input')

# clearing any previous input in search bar

search.clear()

# Puting 'cars' to search button and click on seach

search.send_keys('cars')
button=driver.find_element(By.XPATH,'//span[@class="n6h3Rc"]')
button.click()

# %%
# Scrolling window using ScrollBy

driver.execute_script("window.scrollBy(0,10000)","")

# %%
image_tag= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

url=[]
for img in image_tag:
    x= img.get_attribute('src')
    if x is not None:
        if(x[0:4] == 'http'):
            url.append(x)

# %%
len(url)
# Out:
# 41

# %%
for i in range(len(url)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(url[i])
    file = open(r"C:\Users\Pavan Krishna\Desktop\flip robo\web scraping 3\cars" +str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images

# %%
#Scraping for Machine Learning:
# Finding search

search=driver.find_element(By.XPATH,'/html/body/c-wiz/c-wiz/div/div[3]/div[2]/div/div[1]/form/div[1]/div[2]/div/div[2]/input')

# clearing any previous input in search bar

search.clear()

# Puting 'Machine Learning' to search button and click on seach

search.send_keys('Machine Learning')
button=driver.find_element(By.XPATH,'//span[@class="n6h3Rc"]')
button.click()

# %%
# Scrolling window using ScrollBy

driver.execute_script("window.scrollBy(0,10000)","")

# %%
image_tag= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

url=[]
for img in image_tag:
    x= img.get_attribute('src')
    if x is not None:
        if(x[0:4] == 'http'):
            url.append(x)

# %%
len(url)
# Out:
# 33

# %%
for i in range(len(url)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(url[i])
    file = open(r"C:\Users\Pavan Krishna\Desktop\flip robo\web scraping 3" +str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images

# %% [markdown]
# Q4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV

# %%
#First connect to the driver

driver= webdriver.Chrome(r"chromedriver_win32.exe")

#open the page in automated chrome browser

driver.get('http://www.flipkart.com/')
time.sleep(1)

# %%
#close popup window

try:
    popup = driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _2doB4z"]')
    popup.click()
except NoSuchElementException:
    print('Popup Window is not present')

# %%
# Finding Search bar

search=driver.find_element(By.XPATH,'//input[@class="_3704LK"]')

# Clearing any previous input in search bar

search.clear()

# Putting 'Oneplus Nord' to search button and click on seach

search.send_keys('Oneplus Nord')
button=driver.find_element(By.XPATH,'//button[@class="L0Z3Pu"]')
button.click()

# %%
# Making empty list to scrape data
brand =[]
smartphone =[]
colour =[]
ram=[]
rom =[]
primary_camera=[]
dual_camera=[]
display_size=[]
battery_capacity=[]
price =[]
url=[]

# %%
url_tags =driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
for i in url_tags:
    x=i.get_attribute('href')
    url.append(x)

# %%
len(url)
# Out:
# 24

# %%
for i in url:
    driver.get(i)
    time.sleep(1)

# %%
    # Expanding specification table by clicking on read more button
    try:
        Read_more=driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _1FH0tX"]')
        Read_more.click()
        
    except NoSuchElementException:
        print('NoSuchElementException Occur')
        pass
    
    # Extracting Brand Name
    try:
        brand_tags=driver.find_element(By.XPATH,'//span[@class="B_NuCI"]')
        brand.append(brand_tags.text.split()[0])
    
    except NoSuchElementException:
        brand.append('-')
        
    # Extracting smartphone Name
    try:
        smartphone_tags=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[3]/td[2]/ul/li')
        smartphone.append(smartphone_tags.text)
    
    except NoSuchElementException:
        smartphone.append('-')
        
    # Extracting Colour
    try:
        colour_tag =driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')
        colour.append(colour_tag.text)
    
    except NoSuchElementException:
        colour.append('-')
        
    # Extracting Storage ram
    try:
        ram_tag =driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table/tbody/tr[2]/td[2]/ul/li')
        ram.append(ram_tag.text)
        
    except NoSuchElementException:
        ram.append('-')
    
        
    # Extracting Storage rom
    try:
        rom_tag =driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table/tbody/tr[1]/td[2]/ul/li')
        rom.append(rom_tag.text)
        
    except NoSuchElementException:
        rom.append('-')
        
    # Extracting Primary camera details
    p=[]
    try:
        camera_tags=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table/tbody/tr[1]/td[2]/ul/li')
        p.append(camera_tags.text)
        for i in p:
            if i=='Yes':
                primary_camera.append('--')
            else:
                primary_camera.append(i)
                
    except NoSuchElementException:
        primary_camera.append('-')
                
        
    # Extracting Dual camera lens details
    try:
        dual_camera_tags=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table/tbody/tr[2]/td[2]/ul/li')
        dual_camera.append(dual_camera_tags.text)
    
    except NoSuchElementException:
        dual_camera.append('-')
     
     
    # Extracting Display size details
    try:
        display_size_tags=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][2]/table/tbody/tr[1]/td[2]/ul/li')
        display_size.append(display_size_tags.text)
    
    except NoSuchElementException:
        display_size.append('-')
      
      
    # Extracting battery capacity details
    l=[]
    try:
        battery_capacity_tags=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][7]/table/tbody/tr/td[2]/ul/li')
        l.append(battery_capacity_tags.text)
        for i in l:
            if len(i)== 8:
                battery_capacity.append(i)
            else:
                battery_capacity.append("--")
    
    except NoSuchElementException:
        battery_capacity.append('-')
        
        
    # Extracting price details
    try:
        price_tags=driver.find_element(By.XPATH,'//div[@class="_30jeq3 _16Jk6d"]')
        price.append(price_tags.text)
    
    except NoSuchElementException:
        price.append('-')

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(brand,smartphone,colour, ram,rom,primary_camera,dual_camera,display_size,battery_capacity,price,url))

data= pd.DataFrame (data_list,
    columns =['Brand_Name', 'Smartphone Name', 'Colour', 'RAM','Storage(ROM)', 'Primary Camera','Dual Camera',
              'Display Size', 'Battery Capacity','Price', 'URL'],
    index = pd.RangeIndex(start=1, stop=23, name='Sr. No.'))

#Print the required data

data.to_csv("oneplus_details.csv", index= False)

print("Details of each product listed in first page from flipkart.com:\n")
data
# Out:
# Details of each product listed in first page from flipkart.com:
#         Brand_Name    Smartphone Name          Colour    RAM Storage(ROM)  \
# Sr. No.
# 1          OnePlus  Nord CE 2 Lite 5G       Blue Tide   8 GB       128 GB
# 2          OnePlus  Nord CE 2 Lite 5G      Black Dusk   6 GB       128 GB
# 3          OnePlus  Nord CE 2 Lite 5G       Blue Tide   6 GB       128 GB
# 4          OnePlus         Nord 2T 5G     Gray Shadow   8 GB       128 GB
# 5          OnePlus         Nord 2T 5G     Gray Shadow   8 GB       128 GB
# 6          OnePlus         Nord 2T 5G        Jade Fog   8 GB       128 GB
# 7          OnePlus         Nord 2T 5G        Jade Fog   8 GB       128 GB
# 8          OnePlus  Nord CE 2 Lite 5G      Black Dusk   8 GB       128 GB
# 9          OnePlus         Nord 2T 5G        Jade Fog  12 GB       256 GB
# 10         OnePlus  Nord CE 3 Lite 5G  Chromatic Gray   8 GB       256 GB
# 11         OnePlus          Nord 2 5G     Gray Sierra  12 GB       256 GB
# 12         OnePlus          Nord 2 5G      Green Wood  12 GB       256 GB
# 13         OnePlus         Nord 2T 5G     Gray Shadow   8 GB       128 GB
# 14         OnePlus         Nord 2T 5G     Gray Shadow  12 GB       256 GB
# 15         OnePlus          Nord 2 5G     Gray Sierra   8 GB       128 GB
# 16         OnePlus  Nord CE 3 Lite 5G     Pastel Lime   8 GB       128 GB
# 17         OnePlus       Nord CE 2 5G     Gray Mirror   6 GB       128 GB
# 18         OnePlus          Nord 2 5G       Blue Haze   8 GB       128 GB
# 19         OnePlus         Nord CE 5G       Blue Void  12 GB       128 GB
# 20         OnePlus         Nord CE 5G       Blue Void   8 GB       128 GB
# 21         OnePlus       Nord CE 2 5G     Gray Mirror   8 GB       128 GB
# 22         OnePlus         Nord CE 5G    Charcoal Ink   8 GB       128 GB
#
#             Primary Camera     Dual Camera          Display Size  \
# Sr. No.
# 1         64MP Rear Camera               -  16.74 cm (6.59 inch)
# 2         64MP Rear Camera               -  16.74 cm (6.59 inch)
# 3         64MP Rear Camera               -  16.74 cm (6.59 inch)
# 4         50MP Rear Camera               -   17.02 cm (6.7 inch)
# 5         50MP Rear Camera               -   17.02 cm (6.7 inch)
# 6         50MP Rear Camera               -   17.02 cm (6.7 inch)
# 7         50MP Rear Camera               -   17.02 cm (6.7 inch)
# 8         64MP Rear Camera               -  16.74 cm (6.59 inch)
# 9         50MP Rear Camera               -   17.02 cm (6.7 inch)
# 10       108MP Rear Camera  Primary Camera  17.07 cm (6.72 inch)
# 11        50MP Rear Camera               -  16.33 cm (6.43 inch)
# 12        50MP Rear Camera  Primary Camera  16.33 cm (6.43 inch)
# 13        50MP Rear Camera               -   17.02 cm (6.7 inch)
# 14        50MP Rear Camera               -   17.02 cm (6.7 inch)
# 15        50MP Rear Camera  Primary Camera  16.33 cm (6.43 inch)
# 16       108MP Rear Camera  Primary Camera  17.07 cm (6.72 inch)
# 17        64MP Rear Camera  Primary Camera  16.33 cm (6.43 inch)
# 18        50MP Rear Camera               -  16.33 cm (6.43 inch)
# 19        64MP Rear Camera  Primary Camera  16.33 cm (6.43 inch)
# 20        64MP Rear Camera               -  16.33 cm (6.43 inch)
# 21        50MP Rear Camera               -  16.33 cm (6.43 inch)
# 22        64MP Rear Camera  Primary Camera  16.33 cm (6.43 inch)
#
#         Battery Capacity    Price  \
# Sr. No.
# 1               5000 mAh  ₹21,958
# 2               5000 mAh  ₹18,867
# 3               5000 mAh  ₹19,299
# 4               4500 mAh  ₹28,797
# 5               4500 mAh  ₹28,995
# 6               4500 mAh  ₹28,800
# 7               4500 mAh  ₹28,652
# 8               5000 mAh  ₹21,999
# 9               4500 mAh  ₹33,999
# 10              5000 mAh  ₹21,990
# 11              4500 mAh  ₹33,997
# 12              4500 mAh  ₹33,999
# 13              4500 mAh  ₹28,899
# 14              4500 mAh  ₹32,999
# 15              4500 mAh  ₹29,999
# 16              5000 mAh  ₹19,989
# 17              4500 mAh  ₹23,999
# 18              4500 mAh  ₹29,799
# 19              4500 mAh  ₹30,999
# 20              4500 mAh  ₹24,899
# 21              4500 mAh  ₹25,990
# 22              4500 mAh  ₹23,999
#
#                                                        URL
# Sr. No.
# 1        https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 2        https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 3        https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 4        https://www.flipkart.com/oneplus-nord-2t-5g-gr...
# 5        https://www.flipkart.com/oneplus-nord-2t-5g-gr...
# 6        https://www.flipkart.com/oneplus-nord-2t-5g-ja...
# 7        https://www.flipkart.com/oneplus-nord-2t-5g-ja...
# 8        https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 9        https://www.flipkart.com/oneplus-nord-2t-5g-ja...
# 10       https://www.flipkart.com/oneplus-nord-ce-3-lit...
# 11       https://www.flipkart.com/oneplus-nord-2-5g-gra...
# 12       https://www.flipkart.com/oneplus-nord-2-5g-gre...
# 13       https://www.flipkart.com/oneplus-nord-2t-5g-gr...
# 14       https://www.flipkart.com/oneplus-nord-2t-5g-gr...
# 15       https://www.flipkart.com/oneplus-nord-2-5g-gra...
# 16       https://www.flipkart.com/oneplus-nord-ce-3-lit...
# 17       https://www.flipkart.com/oneplus-nord-ce-2-5g-...
# 18       https://www.flipkart.com/oneplus-nord-2-5g-blu...
# 19       https://www.flipkart.com/oneplus-nord-ce-5g-bl...
# 20       https://www.flipkart.com/oneplus-nord-ce-5g-bl...
# 21       https://www.flipkart.com/oneplus-nord-ce-2-5g-...
# 22       https://www.flipkart.com/oneplus-nord-ce-3-lit...

# %% [markdown]
# Q.5 Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google
# maps.

# %%
#First connect to the driver

ddriver= webdriver.Chrome(r"chromedriver_win32.exe")

#open the page in automated chrome browser

driver.get('https://www.google.co.in/maps')
time.sleep(1)

# %%
# Finding Search bar

search=driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/form/div[2]/div[3]/div/input[1]')

# Clearing any previous input in search bar

search.clear()

# Putting 'Kolkata' to search button and click on seach

search.send_keys('Kolkata')
button=driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/div[1]/button')
button.click()

# %%
# finding the current url

current_URL=driver.current_url

print('Current url for given location is :',current_URL)
# Out:
# Current url for given location is : https://www.google.co.in/maps/place/Kolkata,+West+Bengal/@22.5354064,88.2649507,12z/data=!3m1!4b1!4m6!3m5!1s0x39f882db4908f667:0x43e330e68f6c2cbc!8m2!3d22.572646!4d88.363895!16zL20vMGN2dzk

# %%
# finding total location from URL

if "@" in current_URL:
        loc = current_URL.split('@')[1].split(',*/data')[0].split(',')
loc
# Out:
# ['22.5354064',
#  '88.2649507',
#  '12z/data=!3m1!4b1!4m6!3m5!1s0x39f882db4908f667:0x43e330e68f6c2cbc!8m2!3d22.572646!4d88.363895!16zL20vMGN2dzk']

# %%
# scraping latitude and longitude from URL

try:
    if "@" in current_URL:
        loc = current_URL.split('@')[1].split(',*/data')[0].split(',')
        print('Latitude of given Location:',loc[0])
        print('Longitude of given Location:',loc[1])
except:
    print('Location details is not found in URL')
# Out:
# Latitude of given Location: 22.5354064
# Longitude of given Location: 88.2649507

# %% [markdown]
# Q.6 Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21)
# from trak.in.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"chromedriver_win32.exe")

# %%
# get webpage
driver.get("https://trak.in/")
time.sleep(2)
driver.maximize_window()

# %%
# Clicking 'funding deals'
funding_deals_tags = driver.find_element(By.XPATH,'//li[@id="menu-item-1237902"]/a')
x= funding_deals_tags.get_attribute('href')
driver.get(x)

# %%
## No story is available..

# %% [markdown]
# Q.7 Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"chromedriver_win32.exe")
#open the page in automated chrome browser

driver.get('https://www.digit.in')
time.sleep(2)

# %%
# Clicking on top 10 option button in menu bar

gaming= driver.find_element(By.XPATH,'/html/body/div[2]/div/ul/li[5]/span')
gaming.click()
time.sleep(2)

# %%
# Clicking on Laptop
lap= driver.find_element(By.XPATH,'/html/body/div[2]/div/ul/li[5]/div[3]/div/div[2]/div/ul[3]/li[4]/a')
lap.click()
time.sleep(2)

# %%
# Clicking on Best gaming laptops

gaming_lap =driver.find_element(By.XPATH,'/html/body/div[3]/div/div[2]/div[2]/h2/a').get_attribute('href')
driver.get(gaming_lap)
time.sleep(3)

# %%
# Clicking on Best gaming laptops

gaming_lap =driver.find_element(By.XPATH,'/html/body/div[3]/div/div[2]/div[2]/h3/a').get_attribute('href')
driver.get(gaming_lap)
time.sleep(3)

# %%
# Making Empty list for scraping data

laptop_model =[]
processor =[]
display = []
OS =[]
memory =[]
graphics_processor =[]
dimension =[]
weight =[]
url=[]

# %%
# Extracting Laptop model

laptop_tags =driver.find_elements(By.XPATH, '//div[@class="heading-wraper"]')
for i in laptop_tags:
    laptop_model.append(i.text)

# Extracting processor

processor_tags =driver.find_elements(By.XPATH,'//div[@class="value"]')
for i in processor_tags:
    processor.append(i.text)
    
# Extracting display

display_tags =driver.find_elements(By.XPATH,'//div[@class="value"]/p')
for i in display_tags:
    display.append(i.text)

# Extracting OS

OS_tags =driver.find_elements(By.XPATH,'//div[@class="value"]')
for i in OS_tags:
    OS.append(i.text)    

# Extracting memory

memory_tags =driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[6]/td[3]')
for i in memory_tags:
    memory.append(i.text)
    
# Extracting graphics_processor

graphics_processor_tags =driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[7]/td[3]')
for i in graphics_processor_tags:
    graphics_processor.append(i.text)
    
# Extracting dimension

dimension_tags =driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[8]/td[3]')
for i in dimension_tags:
    dimension.append(i.text.split("&")[0])
    
# Extracting weight

weight_tags =driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[8]/td[3]')
for i in weight_tags:
    weight.append(i.text.split("&")[1])
    
# Extracting url details

url_tags =driver.find_elements(By.XPATH,'//div[@class="left_side"]/a')
for i in url_tags:
    url.append(i.get_attribute("href"))

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(laptop_model,processor,display,OS,memory,graphics_processor,dimension,weight,url))

data= pd.DataFrame (data_list,
    columns =['Laptop Model', 'Processor', 'Display', 'OS','Memory','Graphics Processor',
              'Dimension', 'Weight', 'URL'], index= pd.RangeIndex(start=1, stop=11, name='Sr. No.'))

#Print the required data

data.to_csv("Digit_laptop_details.csv", index= False)

print("Details of all the available details of best gaming laptops from digit.in:\n")
data
# Out:
# Details of all the available details of best gaming laptops from digit.in:
#         Laptop Model Processor Display   OS Memory Graphics Processor  \
# Sr. No.
# 1                NaN       NaN     NaN  NaN    NaN                NaN
# 2                NaN       NaN     NaN  NaN    NaN                NaN
# 3                NaN       NaN     NaN  NaN    NaN                NaN
# 4                NaN       NaN     NaN  NaN    NaN                NaN
# 5                NaN       NaN     NaN  NaN    NaN                NaN
# 6                NaN       NaN     NaN  NaN    NaN                NaN
# 7                NaN       NaN     NaN  NaN    NaN                NaN
# 8                NaN       NaN     NaN  NaN    NaN                NaN
# 9                NaN       NaN     NaN  NaN    NaN                NaN
# 10               NaN       NaN     NaN  NaN    NaN                NaN
#
#         Dimension Weight  URL
# Sr. No.
# 1             NaN    NaN  NaN
# 2             NaN    NaN  NaN
# 3             NaN    NaN  NaN
# 4             NaN    NaN  NaN
# 5             NaN    NaN  NaN
# 6             NaN    NaN  NaN
# 7             NaN    NaN  NaN
# 8             NaN    NaN  NaN
# 9             NaN    NaN  NaN
# 10            NaN    NaN  NaN

# %% [markdown]
# 8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be
# scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"chromedriver_win32.exe")

#open the page in automated chrome browse

driver.get('https://www.forbes.com/billionaires/')
time.sleep(2)

# %%
#close popup window

try:
    popup = driver.find_element(By.XPATH,'/html/body/div[7]/div/button')
    popup.click()
except NoSuchElementException:
    print('Popup Window is not present')
# Out:
# Popup Window is not present

# %%
# Empty list to scrap data
rank =[]
name=[]
net_worth=[]
age=[]
citizenship=[]
source=[]
industry=[]

# %%
# Extracting Rank No
rank_tag =driver.find_elements(By.XPATH,'//div[@class="Table_dataCell__2QCve"]')
for i in rank_tag:
    rank.append(i.text.split(".")[0])
len(rank)
# Out:
# 800

# %%
# Extacting name
name_tag = driver.find_elements(By.XPATH,'//div[@class="Table_dataCell__2QCve"]')
for i in name_tag[0:200]:
    name.append(i.text)
len(name)
# Out:
# 800

# %%
# Extacting networth
nt_tag = driver.find_elements(By.XPATH,'//div[@class="Table_netWorth___L4R5 Table_dataCell__2QCve"]')
for i in nt_tag:
    net_worth.append(i.text)
len(net_worth)
# Out:
# 200

# %%
# Extacting age
age_tag = driver.find_elements(By.XPATH,'//div[@class="Table_dataCell__2QCve"]')
for i in age_tag:
    age.append(i.text)
len(age)
# Out:
# 800

# %%
# Extacting citizen
ctzn_tag = driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"]')
for i in ctzn_tag:
    citizenship.append(i.text)
len(citizenship)
# Out:
# 1400

# %%
# Extracting Source
try:
    source_tag =driver.find_elements(By.XPATH,'//div[@class="source-column"]')
    for i in source_tag:
        source.append(i.text)
except:
    source_tag =driver.find_elements(By.XPATH,'//*[@id="jeff-bezos"]/div[6]/div/div[1]')
    source.append(i.text)
    
len(source)
# Out:
# 1600

# %%
# Extracting Citizenship
citizen_tag =driver.find_elements(By.XPATH,'//div[@class="countryOfCitizenship"]')
for i in citizen_tag:
    citizenship.append(i.text)
    
len(citizenship)
# Out:
# 1400

# %%
# Extracting Industry
ind_tag =driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"]')
for i in ind_tag:
    industry.append(i.text)
len(industry)
# Out:
# 2200

# %%
df = pd.DataFrame({'Rank':rank[0:100],' name ':name[0:100],' net_worth ':net_worth[0:100],' age ':age[0:100],'citizenship':citizenship[0:100],'source':source[0:100],'citizenship':citizenship[0:100],'industry':industry[0:100]})

# %%
df
# Out:
#                         Rank                     name   net_worth   \
# 0   Bernard Arnault & family  Bernard Arnault & family      $211 B
# 1                         74                        74      $180 B
# 2                       LVMH                      LVMH      $114 B
# 3                                                           $107 B
# 4                  Elon Musk                 Elon Musk      $106 B
# ..                       ...                       ...         ...
# 95                                                         $17.5 B
# 96      Phil Knight & family      Phil Knight & family     $17.4 B
# 97                        85                        85     $17.4 B
# 98                      Nike                      Nike     $17.1 B
# 99                                                         $16.7 B
#
#                         age                citizenship  \
# 0   Bernard Arnault & family                         1
# 1                         74  Bernard Arnault & family
# 2                       LVMH                    $211 B
# 3                                                   74
# 4                  Elon Musk                    France
# ..                       ...                       ...
# 95                                       United States
# 96      Phil Knight & family                    Google
# 97                        85
# 98                      Nike                        15
# 99                                      Zhong Shanshan
#
#                       source                  industry
# 0   Bernard Arnault & family  Bernard Arnault & family
# 1                         74                        74
# 2                       LVMH                      LVMH
# 3
# 4                  Elon Musk                 Elon Musk
# ..                       ...                       ...
# 95
# 96      Phil Knight & family      Phil Knight & family
# 97                        85                        85
# 98                      Nike                      Nike
# 99
#
# [100 rows x 7 columns]

# %% [markdown]
#  Q9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"chromedriver_win32.exe")

#open the page in automated chrome browse

driver.get('https://www.youtube.com')
time.sleep(2)

# %%
# Finding search menu
search=driver.find_element(By.XPATH,'//input[@id="search"]') 

#Putting input video name by user

search.send_keys('The Kid LAROI, Justin Bieber - STAY')

# Finding Search button and clicking

button=driver.find_element(By.XPATH,'//button[@id="search-icon-legacy"]/yt-icon')  
button.click()
time.sleep(2)

# %%
from time import sleep

# Loading all comments
i = 1 
while True:
    i += 500
    driver.execute_script(f"window.scrollTo(0, {i});")
        
    all_box = driver.find_elements(By.XPATH,'//ytd-comment-thread-renderer')
    
    sleep(1)
    
    if len(all_box) > 500:
        break

# %%
full = []
for i in all_box:
    comment = i.find_element(By.XPATH,'.//ytd-expander[@id="expander"]').text
    upvote = i.find_element(By.XPATH,'.//span[@id="vote-count-middle"]').text
    time = i.find_element(By.XPATH,'.//div[@id="header-author"]//yt-formatted-string/a').text
    
    full.append({
        'comment' : comment,
        'upvote' : upvote,
        'time' : time
    })
    
data = pd.DataFrame(full)
data
# Out:
#                                                comment upvote  \
# 0            this song is going to be a worldwide hit     14K
# 1                           Lyrics!\n\nSTAY\nRead more     18
# 2    I do the same thing, I told you that I never w...      6
# 3                                                        246K
# 4    2 years later and this song still hits differe...    611
# ..                                                 ...    ...
# 510                                                         1
# 511                        This song is just beautiful   3.7K
# 512                                     best song EVER      2
# 513  Its been  5 years and scientists still couldnt...      1
# 514  The kid Laroi is of my favourite rapper stay i...
#
#                       time
# 0               1 year ago
# 1    18 hours ago (edited)
# 2                1 day ago
# 3               1 year ago
# 4              3 weeks ago
# ..                     ...
# 510             7 days ago
# 511             1 year ago
# 512            4 weeks ago
# 513            3 weeks ago
# 514             8 days ago
#
# [515 rows x 3 columns]

# %% [markdown]
# 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in
# “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews,
# overall reviews, privates from price, dorms from price, facilities and property description.

# %%
# Connecting to webdriver

driver= webdriver.Chrome(r"chromedriver_win32.exe")

#open the page in automated chrome browse

driver.get(" https://www.hostelworld.com/")

# %%
# Finding search menu

search = driver.find_element(By.XPATH,'//input[@id="location-text-input-field"]')
search.send_keys("London")

# %%
# clicking london

london = driver.find_element(By.XPATH,'//button[@class="button primary large"]')
london.click()

# %%
#empty list for storing required data

hostel_name = []
distance = []
facilities =[]
url = []

# %%
#fetching hostel name
try:
    name_tags = driver.find_elements(By.XPATH,'//h2[@class="title title-6"]')
    for i in name_tags:
        hostel_name.append(i.text)
except NoSuchElementException:
    hostel_name.append('-')

# %%
len(hostel_name)
# Out:
# 30

# %%
#fetching distance
try:
    distance_tags = driver.find_elements(By.XPATH,'//span[@class="description"]')
    for i in distance_tags:
        distance.append(i.text.split("-")[1])
except NoSuchElementException:
    distance.append('-')

# %%
len(distance)
# Out:
# 30

# %%
url_tags =driver.find_elements(By.XPATH,'//h2[@class="title title-6"]/a')
for i in url_tags:
    x=i.get_attribute('href')
    url.append(x)
url
# Out:
# ['https://www.hostelworld.com/pwa/hosteldetails.php/Wombat-s-City-Hostel-London/London/88047?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Hostel-One-Notting-Hill/London/291433?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Generator-London/London/510?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Urbany-Hostel-London/London/303427?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Safestay-London-Elephant-Castle/London/55551?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Safestay-London-Kensington-Holland-Park/London/93920?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/No-8-Willesden-Hostel-London/London/18420?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/No-8-Seven-Sisters/London/91108?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/London-Backpackers/London/527?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Phoenix-Hostel/London/48221?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Hammersmith/London/20976?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/PubLove-The-Steam-Engine-Waterloo/London/29389?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Greenwich/London/501?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Selina-Camden/London/310274?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Book-a-Bed-Hostels/London/14746?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Bell-House-Hostel/London/315821?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Hostelle-London/London/316723?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Kensal-Green-Backpackers/London/4483?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/PubLove-The-White-Ferry-Victoria/London/39761?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/PubLove-The-Crown-Battersea/London/60336?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Hootananny-Hostel/London/24068?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Elmwood-Hotel/London/34338?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/PubLove-The-Rose-Crown/London/297123?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/London-Waterloo-Hostel/London/39493?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Tony-s-House-Hotel/London/8503?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/PubLove-The-Exmouth-Arms-Euston/London/93796?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/PubLove-The-Green-Man-Paddington/London/21953?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/City-Hotel-Carlton/London/27551?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/TLK-Apartments-Hotel/London/304817?from=2023-05-15&to=2023-05-18&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Enrico-Hotel/London/5585?from=2023-05-15&to=2023-05-18&guests=2']

# %%
len(url)
# Out:
# 30

# %%
#fetching distance
try:
    facilities_tags = driver.find_elements(By.XPATH,'//div[@class="facilities-label facilities"]')
    for i in facilities_tags:
        facilities.append(i.text.replace("\n",","))
except NoSuchElementException:
    facilities.append('-')
facilities
# Out:
# ['Free WiFi,Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free WiFi,Follows Covid-19 sanitation guidance',
#  'Free WiFi,Follows Covid-19 sanitation guidance',
#  'Free WiFi,Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free WiFi,Follows Covid-19 sanitation guidance',
#  'Free WiFi,Follows Covid-19 sanitation guidance',
#  'Free WiFi,Follows Covid-19 sanitation guidance',
#  'Free WiFi,Follows Covid-19 sanitation guidance',
#  'Free WiFi,Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free WiFi,Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free WiFi',
#  'Free WiFi',
#  'Free WiFi,Follows Covid-19 sanitation guidance',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free WiFi',
#  'Free WiFi,Free Breakfast',
#  '',
#  'Free WiFi',
#  'Free WiFi,Follows Covid-19 sanitation guidance',
#  'Free Breakfast',
#  'Free WiFi',
#  'Free WiFi',
#  '',
#  'Free WiFi',
#  'Free WiFi']

# %%
len(facilities)
# Out:
# 30

# %%
# Creating DataFrame for scrapped data

df = pd.DataFrame({'hostel_name':hostel_name[0:15],'distance':distance[0:15],'facilities':facilities[0:15],'url':url[0:15]})

# %%
df
# Out:
#                                 hostel_name                  distance  \
# 0               Wombat's City Hostel London    3.6km from city centre
# 1                   Hostel One Notting Hill    5.5km from city centre
# 2                          Generator London      3km from city centre
# 3                      Urbany Hostel London    5.4km from city centre
# 4         Safestay London Elephant & Castle    1.7km from city centre
# 5   Safestay London Kensington Holland Park    5.8km from city centre
# 6              No.8 Willesden Hostel London     10km from city centre
# 7                        No.8 Seven Sisters      9km from city centre
# 8                        London Backpackers   11.9km from city centre
# 9                            Phoenix Hostel    4.2km from city centre
# 10             St Christopher's Hammersmith    7.5km from city centre
# 11     PubLove @ The Steam Engine, Waterloo    0.5km from city centre
# 12               St Christopher's Greenwich    7.6km from city centre
# 13                            Selina Camden    5.5km from city centre
# 14                       Book a Bed Hostels    6.9km from city centre
#
#                                         facilities  \
# 0   Free WiFi,Follows Covid-19 sanitation guidance
# 1                                        Free WiFi
# 2   Free WiFi,Follows Covid-19 sanitation guidance
# 3   Free WiFi,Follows Covid-19 sanitation guidance
# 4   Free WiFi,Follows Covid-19 sanitation guidance
# 5                                        Free WiFi
# 6   Free WiFi,Follows Covid-19 sanitation guidance
# 7   Free WiFi,Follows Covid-19 sanitation guidance
# 8   Free WiFi,Follows Covid-19 sanitation guidance
# 9   Free WiFi,Follows Covid-19 sanitation guidance
# 10  Free WiFi,Follows Covid-19 sanitation guidance
# 11                                       Free WiFi
# 12  Free WiFi,Follows Covid-19 sanitation guidance
# 13                                       Free WiFi
# 14                                       Free WiFi
#
#                                                   url
# 0   https://www.hostelworld.com/pwa/hosteldetails....
# 1   https://www.hostelworld.com/pwa/hosteldetails....
# 2   https://www.hostelworld.com/pwa/hosteldetails....
# 3   https://www.hostelworld.com/pwa/hosteldetails....
# 4   https://www.hostelworld.com/pwa/hosteldetails....
# 5   https://www.hostelworld.com/pwa/hosteldetails....
# 6   https://www.hostelworld.com/pwa/hosteldetails....
# 7   https://www.hostelworld.com/pwa/hosteldetails....
# 8   https://www.hostelworld.com/pwa/hosteldetails....
# 9   https://www.hostelworld.com/pwa/hosteldetails....
# 10  https://www.hostelworld.com/pwa/hosteldetails....
# 11  https://www.hostelworld.com/pwa/hosteldetails....
# 12  https://www.hostelworld.com/pwa/hosteldetails....
# 13  https://www.hostelworld.com/pwa/hosteldetails....
# 14  https://www.hostelworld.com/pwa/hosteldetails....

# %% [markdown]
# end of the assignment
